# %%
import pandas as pd
filePath = '/content/League of Legends.csv'
data = pd.read_csv(filePath)
data
# Out:
#          Champion  Kill  Death  Assist       KDA Match Duration Win/Lose  \
# 0    Renata Glasc     2     12      18  1.666667          35:07        L
# 1           Yuumi     0      4       8  2.000000          37:00        L
# 2           Yuumi     2      4       5  1.750000          22:12        L
# 3           Swain     0     10       5  0.500000          28:33        L
# 4           Yuumi     4      7      12  2.285714          42:05        L
# ..            ...   ...    ...     ...       ...            ...      ...
# 291        Veigar     1      7       1  0.285714          29:40        L
# 292         Yuumi     4      8      29  4.125000          46:38        L
# 293    Blitzcrank     6      9      27  3.666667          46:38        W
# 294         Yuumi     1      4       5  1.500000          36:32        L
# 295     Seraphine     3      4      15  4.500000          36:32        W
#
#         Role   Player
# 0    Support  Joyanta
# 1    Support  Joyanta
# ...

# %%
# Identify the column names
column = list(data.columns)
print(column)
# Out:
# ['Champion', 'Kill', 'Death', 'Assist', 'KDA', 'Match Duration', 'Win/Lose', 'Role', 'Player']

# %%
# Identify the data types of the data
dataTypes = data.dtypes
print(dataTypes)
# Out:
# Champion           object
# Kill                int64
# Death               int64
# Assist              int64
# KDA               float64
# Match Duration     object
# Win/Lose           object
# Role               object
# Player             object
# dtype: object

# %%
# Display the total number of records
TotalRec = len(data)
print(TotalRec)
# Out:
# 296

# %%
# Display the first 20 records
first20 = data.head(20)
print(first20)
# Out:
#         Champion  Kill  Death  Assist       KDA Match Duration Win/Lose  \
# 0   Renata Glasc     2     12      18  1.666667          35:07        L
# 1          Yuumi     0      4       8  2.000000          37:00        L
# 2          Yuumi     2      4       5  1.750000          22:12        L
# 3          Swain     0     10       5  0.500000          28:33        L
# 4          Yuumi     4      7      12  2.285714          42:05        L
# 5          Yuumi     0      2       0  0.000000          21:52        L
# 6          Yuumi     0      4      23  5.750000          36:32        L
# 7          Yuumi     4      8      11  1.875000          31:07        L
# 8          Yuumi     8     10      23  3.100000          48:40        W
# 9          Yuumi     1      3       0  0.333333          15:42        L
# 10         Yuumi     0      3      12  4.000000          23:58        W
# 11         Yuumi     2      1       6  8.000000          25:57        W
# ...

# %%
# Display the last 20 records
last20 = data.tail(20)
print(last20)
# Out:
#        Champion  Kill  Death  Assist        KDA Match Duration Win/Lose  \
# 276       Yuumi     1      2      16   8.500000          28:51        W
# 277  Tahm Kench     5      8       4   1.125000          28:51        L
# 278       Yuumi     4      8      40   5.500000          50:59        W
# 279   Seraphine     4     11      28   2.909091          50:59        L
# 280       Yuumi     2      9       9   1.222222          30:31        L
# 281  Blitzcrank     2      6      28   5.000000          30:31        W
# 282       Yuumi     0      4      18   4.500000          30:09        W
# 283         Lux     3      5      16   3.800000          30:09        L
# 284       Yuumi     0      1       7   7.000000          16:28        W
# 285       Swain     0      3       3   1.000000          16:28        L
# 286       Yuumi     0      2       4   2.000000          20:04        L
# 287        Ashe     3      2       4   3.500000          20:04        W
# ...

# %%
#Change the Player column to InGameName
data.rename(columns={'Player': 'InGameName'}, inplace=True)
data
# Out:
#          Champion  Kill  Death  Assist       KDA Match Duration Win/Lose  \
# 0    Renata Glasc     2     12      18  1.666667          35:07        L
# 1           Yuumi     0      4       8  2.000000          37:00        L
# 2           Yuumi     2      4       5  1.750000          22:12        L
# 3           Swain     0     10       5  0.500000          28:33        L
# 4           Yuumi     4      7      12  2.285714          42:05        L
# ..            ...   ...    ...     ...       ...            ...      ...
# 291        Veigar     1      7       1  0.285714          29:40        L
# 292         Yuumi     4      8      29  4.125000          46:38        L
# 293    Blitzcrank     6      9      27  3.666667          46:38        W
# 294         Yuumi     1      4       5  1.500000          36:32        L
# 295     Seraphine     3      4      15  4.500000          36:32        W
#
#         Role InGameName
# 0    Support    Joyanta
# 1    Support    Joyanta
# ...

# %%
# Delete KDA column
data = data.drop('KDA', axis = 1)
data
# Out:
#          Champion  Kill  Death  Assist Match Duration Win/Lose     Role  \
# 0    Renata Glasc     2     12      18          35:07        L  Support
# 1           Yuumi     0      4       8          37:00        L  Support
# 2           Yuumi     2      4       5          22:12        L  Support
# 3           Swain     0     10       5          28:33        L  Support
# 4           Yuumi     4      7      12          42:05        L  Support
# ..            ...   ...    ...     ...            ...      ...      ...
# 291        Veigar     1      7       1          29:40        L  Support
# 292         Yuumi     4      8      29          46:38        L  Support
# 293    Blitzcrank     6      9      27          46:38        W  Support
# 294         Yuumi     1      4       5          36:32        L  Support
# 295     Seraphine     3      4      15          36:32        W  Support
#
#     InGameName
# 0      Joyanta
# 1      Joyanta
# 2      Joyanta
# 3      Joyanta
# 4      Joyanta
# ...

# %%
# New column for KDA ratio
def KDA(data):
  if data['Death'] == 0:
    return 0
  return (data['Kill'] + data['Assist']) / data['Death']

data['KDA'] = data.apply(KDA, axis=1)
data
# Out:
#          Champion  Kill  Death  Assist Match Duration Win/Lose     Role  \
# 0    Renata Glasc     2     12      18          35:07        L  Support
# 1           Yuumi     0      4       8          37:00        L  Support
# 2           Yuumi     2      4       5          22:12        L  Support
# 3           Swain     0     10       5          28:33        L  Support
# 4           Yuumi     4      7      12          42:05        L  Support
# ..            ...   ...    ...     ...            ...      ...      ...
# 291        Veigar     1      7       1          29:40        L  Support
# 292         Yuumi     4      8      29          46:38        L  Support
# 293    Blitzcrank     6      9      27          46:38        W  Support
# 294         Yuumi     1      4       5          36:32        L  Support
# 295     Seraphine     3      4      15          36:32        W  Support
#
#     InGameName       KDA
# 0      Joyanta  1.666667
# 1      Joyanta  2.000000
# ...

# %%
# Display the players who've won the match.
dragKill = data[data['Win/Lose'] == 'W']
total = len(dragKill)

print(dragKill)
print("\nNumber of players who have won the match:",total)
# Out:
#        Champion  Kill  Death  Assist Match Duration Win/Lose     Role  \
# 8         Yuumi     8     10      23          48:40        W  Support
# 10        Yuumi     0      3      12          23:58        W  Support
# 11        Yuumi     2      1       6          25:57        W  Support
# 19        Yuumi     6      4      21          38:33        W  Support
# 20        Yuumi     3      5      23          30:57        W  Support
# ..          ...   ...    ...     ...            ...      ...      ...
# 287        Ashe     3      2       4          20:04        W  Support
# 289  Blitzcrank     3      0      14          19:25        W  Support
# 290       Yuumi     2      4      12          29:40        W  Support
# 293  Blitzcrank     6      9      27          46:38        W  Support
# 295   Seraphine     3      4      15          36:32        W  Support
#
#     InGameName       KDA
# 8      Joyanta  3.100000
# 10     Joyanta  4.000000
# 11     Joyanta  8.000000
# ...

# %%
# Display the players who've lost the match.
dragKill = data[data['Win/Lose'] == 'L']
total = len(dragKill)

print(dragKill)
print("\nNumber of players who have lost the match:",total)
# Out:
#          Champion  Kill  Death  Assist Match Duration Win/Lose     Role  \
# 0    Renata Glasc     2     12      18          35:07        L  Support
# 1           Yuumi     0      4       8          37:00        L  Support
# 2           Yuumi     2      4       5          22:12        L  Support
# 3           Swain     0     10       5          28:33        L  Support
# 4           Yuumi     4      7      12          42:05        L  Support
# ..            ...   ...    ...     ...            ...      ...      ...
# 286         Yuumi     0      2       4          20:04        L  Support
# 288         Yuumi     1      6       3          19:25        L  Support
# 291        Veigar     1      7       1          29:40        L  Support
# 292         Yuumi     4      8      29          46:38        L  Support
# 294         Yuumi     1      4       5          36:32        L  Support
#
#     InGameName       KDA
# 0      Joyanta  1.666667
# 1      Joyanta  2.000000
# ...

# %%
# Use numpy to get the average, median, and standard deviation of the KDA
import numpy as np
avgKDA = np.mean(data['KDA'])
medKDA = np.median(data['KDA'])
stdKDA = np.std(data['KDA'])

print("Average KDA:",avgKDA)
print("Median KDA:", medKDA)
print("Standard Deviation of KDA:", stdKDA)
# Out:
# Average KDA: 3.5073347922612625
# Median KDA: 2.2857142857142856
# Standard Deviation of KDA: 3.9605124191448993
